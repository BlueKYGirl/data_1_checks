# %% [markdown]
# # Knowledge Check 2

# %% [markdown]
# I'm using a CSV file from a report I've been working with in the "real world" this week in my job as a
# school librarian. The file is the output of a report I generated of all the videos in my outdated
# educational video DVD and VHS library. I am weeding these over the next week and have been examining
# the age of the videos and the circulation statistics of the videos. A handful of these titles
# aren't easily available to teachers through copyright-legal streaming services and I don't want
# to delete titles that have been used in the past year.

# %% [markdown]
# First, I will import pandas and seaborn.

# %%
import pandas as pd

# %%
import seaborn as sns

# %% [markdown]
# Next, I will read in my file and show the first five rows. Note: when I first did  this, I got an error I'd never
# seen before that I had to Google; one recommendation was to make sure the CSV file was in "UTF" format. When I
# re-saved it that way and pushed it back to the repo, the dataframe read in as expected. I'm so glad I learned about
# that as it may save me headaches with my final project!

# %%
df = pd.read_csv('assets/video_stats_2023.csv')
df.head()
# Out:
#   CopyBarcode        CallNumber  \
# 0     T 40391     VIDEO 004 Com
# 1     T 31105  VIDEO 004.678083
# 2     T 33808   VIDEO 070.4 PHO
# 3     T 40658     VIDEO 300 DRE
# 4     T 40026     VIDEO 300 STO
#
#                                             Title MaterialType  \
# 0  Computer literacy and careers : Get plugged in        Video
# 1                      Danger.com : teens online.        Video
# 2                               The photographers        Video
# 3              The Drew Carey project : volume 1.        Video
# 4        Stossel in the classroom : 2007 edition.        Video
#
#    PublicationYear     Status DateLastAccountedFor DateAcquired  \
# 0              NaN  Available             2/7/2023     4/9/2009
# 1           2005.0  Available             2/7/2023    12/2/2005
# 2           2000.0  Available             2/7/2023    4/12/2006
# 3              NaN  Available             2/7/2023    6/10/2010
# ...

# %% [markdown]
# Next I decided to plot the total circulations for each video against the date the video was acquired. Note:
# if I had more time to play and explore with the seaborn module, I would format the y-axis in such a way that
# would make it more readable. For this assignment, however, this should be acceptable.

# %%
sns.scatterplot(x=df['TotalCirculations'],
                y=df['DateAcquired'])
# Out:
# <AxesSubplot:xlabel='TotalCirculations', ylabel='DateAcquired'>
